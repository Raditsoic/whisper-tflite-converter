# %%
import tensorflow as tf
from transformers import WhisperProcessor, WhisperFeatureExtractor, TFWhisperForConditionalGeneration, WhisperTokenizer
from datasets import load_dataset

# %%
feature_extractor = WhisperFeatureExtractor.from_pretrained("avalonai/whisper-small-id")
tokenizer = WhisperTokenizer.from_pretrained("openai/whisper-small", predict_timestamps=True)
processor = WhisperProcessor(feature_extractor, tokenizer)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
model = TFWhisperForConditionalGeneration.from_pretrained("avalonai/whisper-small-id")

ds = load_dataset("hf-internal-testing/librispeech_asr_dummy", "clean", split="validation")

inputs = feature_extractor(
    ds[0]["audio"]["array"], sampling_rate=ds[0]["audio"]["sampling_rate"], return_tensors="tf"
)
input_features = inputs.input_features

generated_ids = model.generate(input_features=input_features)
print(generated_ids)
transcription = processor.tokenizer.decode(generated_ids[0], skip_special_tokens=True)
print(transcription)
# Out:
# All PyTorch model weights were used when initializing TFWhisperForConditionalGeneration.
#
# All the weights of TFWhisperForConditionalGeneration were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFWhisperForConditionalGeneration for predictions without further training.
# tf.Tensor(
# [[50258 50259 50359 50363   440   342  1220  4316   295  1331  8795 22949
#     433    13   467  2516  3738   281  1565   484   264 41176    13   316
#    3554 10460  1472  2706  1585   293 37889    13   316  5139 31433  8666
#    2489   365  7852    13 37992   311   419 21193   366   452  2954    13
#     316 37889   906  1755   307   264  2368  3278  6702    13 50257]], shape=(1, 59), dtype=int32)
#  The stale smell of old beer lingers. It takes heat to bring out the odor. A cold dip restores health and zest. A salt pickle tastes fine with ham. Taco's al pastor are my favorite. A zestful food is the hot cross bun.

# %%
model.save('./sane/whisper-id-small')
# Out:
# WARNING:absl:Found untraced functions such as serving, encoder_layer_call_fn, encoder_layer_call_and_return_conditional_losses, decoder_layer_call_fn, decoder_layer_call_and_return_conditional_losses while saving (showing 5 of 817). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./sane/whisper-id-small\assets
# INFO:tensorflow:Assets written to: ./sane/whisper-id-small\assets

# %%
class WrapModel(tf.Module):
  def __init__(self, model):
    super(WrapModel, self).__init__()
    self.model = model

  @tf.function(
    input_signature=[
      tf.TensorSpec((1, 80, 3000), tf.float32, name="input_features"),
    ],
  )
  def serving(self, input_features):
    outputs = self.model.generate(
      input_features,
      max_new_tokens=450, 
      return_dict_in_generate=True,
    )
    return {"sequences": outputs["sequences"]}

saved_model_dir = "./sane/whisper-id-small"
tflite_model_path = "./sane/whisper-id-small.tflite"

generate_model = WrapModel(model=model)
tf.saved_model.save(generate_model, saved_model_dir, signatures={"serving_default": generate_model.serving})

converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_dir)
converter.target_spec.supported_ops = [
  tf.lite.OpsSet.TFLITE_BUILTINS, 
  tf.lite.OpsSet.SELECT_TF_OPS 
]
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

with open(tflite_model_path, 'wb') as f:
    f.write(tflite_model)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[120], line 24
#      21 tflite_model_path = "./sane/whisper-id-small.tflite"
#      23 generate_model = GenerateModel(model=model)
# ---> 24 tf.saved_model.save(generate_model, saved_model_dir, signatures={"serving_default": generate_model.serving})
#      26 # Convert the model
#      27 converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_dir)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\saved_model\save.py:1240, in save(obj, export_dir, signatures, options)
#    1238 # pylint: enable=line-too-long
#    1239 metrics.IncrementWriteApi(_SAVE_V2_LABEL)
# -> 1240 save_and_return_nodes(obj, export_dir, signatures, options)
#    1242 metrics.IncrementWrite(write_version="2")
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\saved_model\save.py:1276, in save_and_return_nodes(obj, export_dir, signatures, options, experimental_skip_checkpoint)
#    1272 saved_model = saved_model_pb2.SavedModel()
#    1273 meta_graph_def = saved_model.meta_graphs.add()
#    1275 _, exported_graph, object_saver, asset_info, saved_nodes, node_paths = (
# -> 1276     _build_meta_graph(obj, signatures, options, meta_graph_def))
#    1277 saved_model.saved_model_schema_version = (
#    1278     constants.SAVED_MODEL_SCHEMA_VERSION)
#    1280 # Write the checkpoint, copy assets into the assets directory, and write out
#    1281 # the SavedModel proto itself.
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\saved_model\save.py:1455, in _build_meta_graph(obj, signatures, options, meta_graph_def)
#    1428 """Creates a MetaGraph under a save context.
#    1429
#    1430 Args:
#    (...)
#    1451   saveable_view.node_paths: _SaveableView paths.
#    1452 """
#    1454 with save_context.save_context(options):
# -> 1455   return _build_meta_graph_impl(obj, signatures, options, meta_graph_def)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\saved_model\save.py:1402, in _build_meta_graph_impl(obj, signatures, options, meta_graph_def)
#    1397 if signatures is None:
#    1398   signatures = signature_serialization.find_function_to_export(
#    1399       augmented_graph_view)
#    1401 signatures, wrapped_functions = (
# -> 1402     signature_serialization.canonicalize_signatures(signatures))
#    1403 signature_serialization.validate_augmented_graph_view(augmented_graph_view)
#    1404 signature_map = signature_serialization.create_signature_map(signatures)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\saved_model\signature_serialization.py:131, in canonicalize_signatures(signatures)
#     129 wrapped_functions = {}
#     130 for signature_key, function in signatures.items():
# --> 131   original_function = signature_function = _get_signature(function)
#     132   if signature_function is None:
#     133     raise ValueError(
#     134         "Expected a TensorFlow function for which to generate a signature, "
#     135         f"but got {function}. Only `tf.functions` with an input signature or "
#     136         "concrete functions can be used as a signature.")
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\saved_model\signature_serialization.py:43, in _get_signature(function)
#      40 def _get_signature(function):
#      41   if (isinstance(function, (defun.Function, def_function.Function)) and
#      42       function.input_signature is not None):
# ---> 43     function = function._get_concrete_function_garbage_collected()  # pylint: disable=protected-access
#      44   if not isinstance(function, defun.ConcreteFunction):
#      45     return None
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:1238, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1236   if self._variable_creation_fn is None:
#    1237     initializers = []
# -> 1238     self._initialize(args, kwargs, add_initializers_to=initializers)
#    1239     self._initialize_uninitialized_variables(initializers)
#    1241 if self._created_variables:
#    1242   # In this case we have created variables on the first call, so we run the
#    1243   # version which is guaranteed to never create variables.
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:763, in Function._initialize(self, args, kwds, add_initializers_to)
#     760 self._lifted_initializer_graph = lifted_initializer_graph
#     761 self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     762 self._concrete_variable_creation_fn = (
# --> 763     self._variable_creation_fn    # pylint: disable=protected-access
#     764     ._get_concrete_function_internal_garbage_collected(
#     765         *args, **kwds))
#     767 def invalid_creator_scope(*unused_args, **unused_kwds):
#     768   """Disables variable creation."""
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:171, in TracingCompiler._get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#     169 """Returns a concrete function which cleans up its graph function."""
#     170 with self._lock:
# --> 171   concrete_function, _ = self._maybe_define_concrete_function(args, kwargs)
#     172 return concrete_function
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:166, in TracingCompiler._maybe_define_concrete_function(self, args, kwargs)
#     163   args = self.input_signature
#     164   kwargs = {}
# --> 166 return self._maybe_define_function(args, kwargs)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:396, in TracingCompiler._maybe_define_function(self, args, kwargs)
#     393   args = placeholder_bound_args.args
#     394 kwargs = placeholder_bound_args.kwargs
# --> 396 concrete_function = self._create_concrete_function(
#     397     args, kwargs, func_graph)
#     399 # TODO(b/263520817): Remove access to private attribute.
#     400 graph_capture_container = concrete_function.graph._function_captures  # pylint: disable=protected-access
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:300, in TracingCompiler._create_concrete_function(self, args, kwargs, func_graph)
#     296 else:
#     297   arg_names = base_arg_names
#     299 concrete_function = monomorphic_function.ConcreteFunction(
# --> 300     func_graph_module.func_graph_from_py_func(
#     301         self._name,
#     302         self._python_function,
#     303         args,
#     304         kwargs,
#     305         None,
#     306         func_graph=func_graph,
#     307         autograph=self._autograph,
#     308         autograph_options=self._autograph_options,
#     309         arg_names=arg_names,
#     310         capture_by_value=self._capture_by_value,
#     311         create_placeholders=False),
#     312     self._function_attributes,
#     313     spec=self.function_spec,
#     314     # Tell the ConcreteFunction to clean up its graph once it goes out of
#     315     # scope. This is not the default behavior since it gets used in some
#     316     # places (like Keras) where the FuncGraph lives longer than the
#     317     # ConcreteFunction.
#     318     shared_func_graph=False)
#     319 return concrete_function
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\framework\func_graph.py:1214, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders, acd_record_initial_resource_uses)
#    1211 else:
#    1212   _, original_func = tf_decorator.unwrap(python_func)
# -> 1214 func_outputs = python_func(*func_args, **func_kwargs)
#    1216 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1217 # TensorArrays and `None`s.
#    1218 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:667, in Function._compiler_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     663 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     664   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     665   # the function a weak reference to itself to avoid a reference cycle.
#     666   with OptionalXlaContext(compile_with_xla):
# --> 667     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     668   return out
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:484, in class_method_to_instance_method.<locals>.bound_method_wrapper(*args, **kwargs)
#     479   return wrapped_fn(weak_instance(), *args, **kwargs)
#     481 # If __wrapped__ was replaced, then it is always an unbound function.
#     482 # However, the replacer is still responsible for attaching self properly.
#     483 # TODO(mdan): Is it possible to do it here instead?
# --> 484 return wrapped_fn(*args, **kwargs)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\framework\func_graph.py:1189, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1187 # TODO(mdan): Push this block higher in tf.function's call stack.
#    1188 try:
# -> 1189   return autograph.converted_call(
#    1190       original_func,
#    1191       args,
#    1192       kwargs,
#    1193       options=autograph.ConversionOptions(
#    1194           recursive=True,
#    1195           optional_features=autograph_options,
#    1196           user_requested=True,
#    1197       ))
#    1198 except Exception as e:  # pylint:disable=broad-except
#    1199   if hasattr(e, "ag_error_metadata"):
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_file_w0jqoqx.py:10, in outer_factory.<locals>.inner_factory.<locals>.tf__serving(self, input_features)
#       8 do_return = False
#       9 retval_ = ag__.UndefinedReturnValue()
# ---> 10 outputs = ag__.converted_call(ag__.ld(self).model.generate, (ag__.ld(input_features),), dict(max_new_tokens=1000, return_dict_in_generate=True), fscope)
#      11 try:
#      12     do_return = True
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_fileu24cnpi7.py:459, in outer_factory.<locals>.inner_factory.<locals>.tf__generate(self, inputs, generation_config, logits_processor, seed, return_timestamps, task, language, is_multilingual, prompt_ids, return_token_timestamps, **kwargs)
#     457     pass
#     458 ag__.if_stmt(ag__.ld(return_token_timestamps), if_body_23, else_body_23, get_state_23, set_state_23, ("kwargs['output_attentions']", "kwargs['return_dict_in_generate']"), 2)
# --> 459 outputs = ag__.converted_call(ag__.converted_call(ag__.ld(super), (), None, fscope).generate, (ag__.ld(inputs), ag__.ld(generation_config), ag__.ld(logits_processor)), dict(**ag__.ld(kwargs)), fscope)
#     461 def get_state_24():
#     462     return (ag__.ldu(lambda: outputs['token_timestamps'], "outputs['token_timestamps']"),)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_fileld9tw18u.py:603, in outer_factory.<locals>.inner_factory.<locals>.tf__generate(self, inputs, generation_config, logits_processor, seed, **kwargs)
#     601     ag__.if_stmt(ag__.ld(is_contrastive_search_gen_mode), if_body_32, else_body_32, get_state_32, set_state_32, ('do_return', 'retval_', 'input_ids', 'model_kwargs'), 2)
#     602 logits_warper = ag__.Undefined('logits_warper')
# --> 603 ag__.if_stmt(ag__.ld(is_greedy_gen_mode), if_body_33, else_body_33, get_state_33, set_state_33, ('do_return', 'retval_', 'input_ids', 'model_kwargs'), 2)
#     604 return fscope.ret(retval_, do_return)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\operators\control_flow.py:1266, in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1264   _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1265 else:
# -> 1266   _py_if_stmt(cond, body, orelse)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\operators\control_flow.py:1319, in _py_if_stmt(cond, body, orelse)
#    1317 def _py_if_stmt(cond, body, orelse):
#    1318   """Overload of if_stmt that executes a Python if statement."""
# -> 1319   return body() if cond else orelse()
#
# File ~\AppData\Local\Temp\__autograph_generated_fileld9tw18u.py:466, in outer_factory.<locals>.inner_factory.<locals>.tf__generate.<locals>.if_body_33()
#     464 try:
#     465     do_return = True
# --> 466     retval_ = ag__.converted_call(ag__.ld(self).greedy_search, (ag__.ld(input_ids),), dict(max_length=ag__.ld(generation_config).max_length, pad_token_id=ag__.ld(generation_config).pad_token_id, eos_token_id=ag__.ld(generation_config).eos_token_id, logits_processor=ag__.ld(logits_processor), output_scores=ag__.ld(generation_config).output_scores, return_dict_in_generate=ag__.ld(generation_config).return_dict_in_generate, **ag__.ld(model_kwargs)), fscope)
#     467 except:
#     468     do_return = False
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_filetoh26xdl.py:318, in outer_factory.<locals>.inner_factory.<locals>.tf__greedy_search(self, input_ids, max_length, pad_token_id, eos_token_id, logits_processor, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, **model_kwargs)
#     316             raise
#     317         return fscope_2.ret(retval__2, do_return_2)
# --> 318 generated, finished_sequences, cur_len, model_kwargs = ag__.converted_call(ag__.ld(greedy_search_body_fn), (ag__.ld(generated), ag__.ld(finished_sequences), ag__.ld(cur_len), ag__.ld(model_kwargs)), None, fscope)
#     319 maximum_iterations = ag__.ld(max_length) - ag__.ld(cur_len)
#     320 generated, _, cur_len, _ = ag__.converted_call(ag__.ld(tf).while_loop, (ag__.ld(greedy_search_cond_fn), ag__.ld(greedy_search_body_fn), (ag__.ld(generated), ag__.ld(finished_sequences), ag__.ld(cur_len), ag__.ld(model_kwargs))), dict(maximum_iterations=ag__.ld(maximum_iterations)), fscope)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:339, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     337 if is_autograph_artifact(f):
#     338   logging.log(2, 'Permanently allowed: %s: AutoGraph artifact', f)
# --> 339   return _call_unconverted(f, args, kwargs, options)
#     341 # If this is a partial, unwrap it and redo all the checks.
#     342 if isinstance(f, functools.partial):
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     457 if kwargs is not None:
#     458   return f(*args, **kwargs)
# --> 459 return f(*args)
#
# File ~\AppData\Local\Temp\__autograph_generated_filetoh26xdl.py:152, in outer_factory.<locals>.inner_factory.<locals>.tf__greedy_search.<locals>.greedy_search_body_fn(generated, finished_sequences, cur_len, model_kwargs)
#     150 ag__.if_stmt(ag__.or_(lambda: ag__.converted_call(ag__.ld(model_kwargs).get, ('past_key_values',), None, fscope_2) is None, lambda: ag__.ld(needs_full_input)), if_body_1, else_body_1, get_state_1, set_state_1, ('input_ids',), 1)
#     151 model_inputs = ag__.converted_call(ag__.ld(self).prepare_inputs_for_generation, (ag__.ld(input_ids),), dict(use_cache=ag__.ld(use_cache), **ag__.ld(model_kwargs)), fscope_2)
# --> 152 model_outputs = ag__.converted_call(ag__.ld(self), (), dict(**ag__.ld(model_inputs), return_dict=True, output_attentions=ag__.ld(output_attentions), output_hidden_states=ag__.ld(output_hidden_states)), fscope_2)
#     153 next_token_logits = ag__.ld(model_outputs).logits[:, -1]
#     154 next_tokens_scores = ag__.converted_call(ag__.ld(logits_processor), (ag__.ld(generated), ag__.ld(next_token_logits), ag__.ld(cur_len)), None, fscope_2)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:458, in _call_unconverted(f, args, kwargs, options, update_cache)
#     455   return f.__self__.call(args, kwargs)
#     457 if kwargs is not None:
# --> 458   return f(*args, **kwargs)
#     459 return f(*args)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\engine\training.py:558, in Model.__call__(self, *args, **kwargs)
#     554         super().__call__(inputs, *copied_args, **copied_kwargs)
#     556     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 558 return super().__call__(*args, **kwargs)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\engine\base_layer.py:1145, in Layer.__call__(self, *args, **kwargs)
#    1140     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1142 with autocast_variable.enable_auto_cast_variables(
#    1143     self._compute_dtype_object
#    1144 ):
# -> 1145     outputs = call_fn(inputs, *args, **kwargs)
#    1147 if self._activity_regularizer:
#    1148     self._handle_activity_regularization(inputs, outputs)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_file6jxazoyg.py:37, in outer_factory.<locals>.inner_factory.<locals>.tf__run_call_with_unpacked_inputs(self, *args, **kwargs)
#      35 try:
#      36     do_return = True
# ---> 37     retval_ = ag__.converted_call(ag__.ld(func), (ag__.ld(self),), dict(**ag__.ld(unpacked_inputs)), fscope)
#      38 except:
#      39     do_return = False
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_fileop786tnj.py:72, in outer_factory.<locals>.inner_factory.<locals>.tf__call(self, input_features, decoder_input_ids, decoder_attention_mask, decoder_position_ids, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, training)
#      70     pass
#      71 ag__.if_stmt(ag__.ld(labels) is not None, if_body_1, else_body_1, get_state_1, set_state_1, ('decoder_input_ids',), 1)
# ---> 72 outputs = ag__.converted_call(ag__.ld(self).model, (ag__.ld(input_features),), dict(decoder_input_ids=ag__.ld(decoder_input_ids), encoder_outputs=ag__.ld(encoder_outputs), decoder_attention_mask=ag__.ld(decoder_attention_mask), decoder_position_ids=ag__.ld(decoder_position_ids), head_mask=ag__.ld(head_mask), decoder_head_mask=ag__.ld(decoder_head_mask), cross_attn_head_mask=ag__.ld(cross_attn_head_mask), past_key_values=ag__.ld(past_key_values), decoder_inputs_embeds=ag__.ld(decoder_inputs_embeds), use_cache=ag__.ld(use_cache), output_attentions=ag__.ld(output_attentions), output_hidden_states=ag__.ld(output_hidden_states), return_dict=ag__.ld(return_dict), training=ag__.ld(training)), fscope)
#      73 decoder_last_hidden_state = ag__.ld(outputs)[0]
#      74 lm_logits = ag__.converted_call(ag__.ld(tf).matmul, (ag__.ld(decoder_last_hidden_state), ag__.converted_call(ag__.ld(self).get_output_embeddings, (), None, fscope).weights), dict(transpose_b=True), fscope)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:458, in _call_unconverted(f, args, kwargs, options, update_cache)
#     455   return f.__self__.call(args, kwargs)
#     457 if kwargs is not None:
# --> 458   return f(*args, **kwargs)
#     459 return f(*args)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\engine\base_layer.py:1145, in Layer.__call__(self, *args, **kwargs)
#    1140     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1142 with autocast_variable.enable_auto_cast_variables(
#    1143     self._compute_dtype_object
#    1144 ):
# -> 1145     outputs = call_fn(inputs, *args, **kwargs)
#    1147 if self._activity_regularizer:
#    1148     self._handle_activity_regularization(inputs, outputs)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_file6jxazoyg.py:37, in outer_factory.<locals>.inner_factory.<locals>.tf__run_call_with_unpacked_inputs(self, *args, **kwargs)
#      35 try:
#      36     do_return = True
# ---> 37     retval_ = ag__.converted_call(ag__.ld(func), (ag__.ld(self),), dict(**ag__.ld(unpacked_inputs)), fscope)
#      38 except:
#      39     do_return = False
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_file7_j3inkz.py:66, in outer_factory.<locals>.inner_factory.<locals>.tf__call(self, input_features, decoder_input_ids, decoder_attention_mask, decoder_position_ids, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, training)
#      64     ag__.if_stmt(ag__.and_(lambda: ag__.ld(return_dict), lambda: ag__.not_(ag__.converted_call(ag__.ld(isinstance), (ag__.ld(encoder_outputs), ag__.ld(TFBaseModelOutput)), None, fscope))), if_body, else_body, get_state, set_state, ('encoder_outputs',), 1)
#      65 ag__.if_stmt(ag__.ld(encoder_outputs) is None, if_body_1, else_body_1, get_state_1, set_state_1, ('encoder_outputs',), 1)
# ---> 66 decoder_outputs = ag__.converted_call(ag__.ld(self).decoder, (), dict(input_ids=ag__.ld(decoder_input_ids), attention_mask=ag__.ld(decoder_attention_mask), position_ids=ag__.ld(decoder_position_ids), encoder_hidden_states=ag__.ld(encoder_outputs)[0], head_mask=ag__.ld(decoder_head_mask), cross_attn_head_mask=ag__.ld(cross_attn_head_mask), past_key_values=ag__.ld(past_key_values), inputs_embeds=ag__.ld(decoder_inputs_embeds), use_cache=ag__.ld(use_cache), output_attentions=ag__.ld(output_attentions), output_hidden_states=ag__.ld(output_hidden_states), return_dict=ag__.ld(return_dict), training=ag__.ld(training)), fscope)
#      68 def get_state_2():
#      69     return (do_return, retval_)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:458, in _call_unconverted(f, args, kwargs, options, update_cache)
#     455   return f.__self__.call(args, kwargs)
#     457 if kwargs is not None:
# --> 458   return f(*args, **kwargs)
#     459 return f(*args)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\engine\base_layer.py:1145, in Layer.__call__(self, *args, **kwargs)
#    1140     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1142 with autocast_variable.enable_auto_cast_variables(
#    1143     self._compute_dtype_object
#    1144 ):
# -> 1145     outputs = call_fn(inputs, *args, **kwargs)
#    1147 if self._activity_regularizer:
#    1148     self._handle_activity_regularization(inputs, outputs)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_file6jxazoyg.py:34, in outer_factory.<locals>.inner_factory.<locals>.tf__run_call_with_unpacked_inputs(self, *args, **kwargs)
#      32 config = ag__.Undefined('config')
#      33 ag__.if_stmt('EncoderDecoder' in ag__.ld(self).__class__.__name__, if_body, else_body, get_state, set_state, ('config',), 1)
# ---> 34 unpacked_inputs = ag__.converted_call(ag__.ld(input_processing), (ag__.ld(func), ag__.ld(config)), dict(**ag__.ld(fn_args_and_kwargs)), fscope)
#      35 try:
#      36     do_return = True
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_fileng62i1qr.py:415, in outer_factory.<locals>.inner_factory.<locals>.tf__input_processing(func, config, **kwargs)
#     413     pass
#     414 boolean_dict = ag__.Undefined('boolean_dict')
# --> 415 ag__.if_stmt(ag__.ld(config) is not None, if_body_23, else_body_23, get_state_28, set_state_28, (), 0)
#     416 try:
#     417     do_return = True
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\operators\control_flow.py:1266, in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1264   _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1265 else:
# -> 1266   _py_if_stmt(cond, body, orelse)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\operators\control_flow.py:1319, in _py_if_stmt(cond, body, orelse)
#    1317 def _py_if_stmt(cond, body, orelse):
#    1318   """Overload of if_stmt that executes a Python if statement."""
# -> 1319   return body() if cond else orelse()
#
# File ~\AppData\Local\Temp\__autograph_generated_fileng62i1qr.py:410, in outer_factory.<locals>.inner_factory.<locals>.tf__input_processing.<locals>.if_body_23()
#     408 def if_body_23():
#     409     boolean_dict = {ag__.ld(k): ag__.ld(v) for k, v in ag__.converted_call(ag__.ld(output).items, (), None, fscope) if ag__.ld(k) in ['return_dict', 'output_attentions', 'output_hidden_states', 'use_cache']}
# --> 410     ag__.converted_call(ag__.ld(output).update, (ag__.converted_call(ag__.ld(booleans_processing), (), dict(config=ag__.ld(config), **ag__.ld(boolean_dict)), fscope),), None, fscope)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:436, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     433     raise
#     434   return _fall_back_unconverted(f, args, kwargs, options, e)
# --> 436 with StackTraceMapper(converted_f), tf_stack.CurrentModuleFilter():
#     437   try:
#     438     if kwargs is not None:
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\util\tf_stack.py:128, in CurrentModuleFilter.__init__(self)
#     126   outer_f = f.f_back
#     127   if outer_f is not None:
# --> 128     filter_filename = inspect.getsourcefile(outer_f)
#     129 self._filename = filter_filename
#     130 # This may be called repeatedly: once on entry by the superclass, then by
#     131 # each child context manager.
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\inspect.py:949, in getsourcefile(object)
#     946 elif any(filename.endswith(s) for s in
#     947              importlib.machinery.EXTENSION_SUFFIXES):
#     948     return None
# --> 949 if os.path.exists(filename):
#     950     return filename
#     951 # only return a non-existent filename if the module has a PEP 302 loader
#
# File <frozen genericpath>:19, in exists(path)
#
# KeyboardInterrupt:
